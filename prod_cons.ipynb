# %%
import numpy as np 

class producer: 
  def __init__ (self, n_workers, latency_per_worker, n_buffers):
    self.n = n_workers
    self.l = latency_per_worker//n_workers
    self.phase = 0 #green or 1 red 
    self.pos = 0
    self.n_buff = n_buffers
    
  
class barrier:
